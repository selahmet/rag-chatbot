# %% [markdown]
# # Generative AI Temel Kavramlar

# %% [markdown]
# ## 1. Temel AI/ML Kavramları
#
# ### Yapay Zeka (Artificial Intelligence - AI)
#
# <img src="assets/ai_concepts.jpg" alt="AI Concept" width="300"/>
#
#
# **Yapay Zeka**, makinelerin insan benzeri düşünme, öğrenme ve problem çözme yeteneklerini sergilemesini sağlayan teknoloji alanıdır. Bu alan; makine öğrenimi (ML), derin öğrenme (DL), doğal dil işleme (NLP), bilgisayarlı görü (CV) ve robotik gibi alt dalları kapsar.
#
#
# ## Makine Öğrenmesi (Machine Learning - ML)
#
# **Makine Öğrenmesi**, bazı görev sınıflarına ve performans ölçütlerine ilişkin deneyimlerden öğrenebilen bir bilgisayar programı.
#
# ### ML Türleri
#
# <img src="assets/ml_type.png" alt="ML Type" width="600"/>
#
# [Kaynak](https://www.researchgate.net/figure/The-main-types-of-machine-learning-Main-approaches-include-classification-and-regression_fig1_354960266)
#
# <details>
#
# <summary><b>🧩 ML Algoritmaları</b></summary>
#
# **1. Supervised Learning Algorithms**
# - **Linear / Logistic Regression** → Parametrik yapıda lineer ilişki modelleme.
# - **Decision Trees / Random Forests** → Entropy veya Gini ile bölünme, ensemble ile overfitting kontrolü.
# - **Support Vector Machines (SVM)** → Maximum-margin hyperplane optimizasyonu, kernel trick ile non-linear sınıflandırma.
# - **k-Nearest Neighbors (kNN)** → Distance metric üzerinden instance-based oylama.
# - **Gradient Boosting (XGBoost, LightGBM, CatBoost)** → Iterative residual learning yaklaşımıyla boosting tabanlı ensemble.
#
# **2. Unsupervised Learning Algorithms**
# - **K-Means Clustering** → Euclidean distance kullanarak centroid-based kümeleme.
# - **Hierarchical Clustering** → Agglomerative veya divisive linkage ile hiyerarşik yapı oluşturma.
# - **Principal Component Analysis (PCA)** → Covariance matrix decomposition ile feature space indirgeme.
# - **Association Rule Learning (Apriori, FP-Growth)** → Frequent itemset mining ve rule extraction için pattern discovery.
#
# **3. Pekiştirmeli Öğrenme Algoritmaları**
# - **Q-Learning**
# - **Deep Q-Networks (DQN)**
# - **Policy Gradient Methods**
#
# </details>
#
# <details>
#
# <summary><b>🧮 Evaluation Metrics (Model Performans Metrikleri)</b></summary>
#
# ### Supervised Learning Metrics
#
# **Classification Metrics**
# - **Accuracy** → Toplam doğru tahminlerin tüm örneklere oranı; baseline karşılaştırması için temel.
# - **Precision** → True Positive / (TP + FP); pozitif tahminin doğruluğunu ölçer.
# - **Recall (Sensitivity)** → TP / (TP + FN); modelin pozitifleri yakalama yeteneği.
# - **F1-Score** → Precision ve Recall’un harmonik ortalaması; class imbalance durumunda tercih edilir.
# - **ROC-AUC** → ROC curve altında kalan alan; TPR-FPR trade-off’unu özetler.
# - **Log Loss / Cross-Entropy** → Probabilistic output’ların uncertainty ve calibration ölçümü.
#
# **Regression Metrics**
# - **Mean Absolute Error (MAE)** → Ortalama mutlak hata; outlier etkisi minimal.
# - **Mean Squared Error (MSE)** → Hataların karesel ortalaması; büyük hatalara duyarlı.
# - **Root Mean Squared Error (RMSE)** → MSE’nin karekökü; hata birimiyle interpretasyon.
# - **R² (Coefficient of Determination)** → Varyansın model tarafından açıklanma oranı; goodness-of-fit göstergesi.
#
#
# ### Unsupervised Learning Metrics
#
# **Clustering Metrics**
# - **Silhouette Score** → Intra-cluster cohesion ve inter-cluster separation’ı tek bir skorla özetler; [-1,1] arası.
# - **Davies-Bouldin Index (DBI)** → Cluster similarity ölçümü; düşük değer = iyi ayrışma.
# - **Calinski-Harabasz Index (CHI)** → Cluster compactness / separation oranı; yüksek değer = iyi yapı.
#
# **Dimensionality Reduction Metrics**
# - **Explained Variance Ratio (EVR)** → PCA bileşenlerinin toplam varyansı ne kadar açıkladığını gösterir.
# - **Reconstruction Error** → Boyut indirgeme sonrası veri yeniden oluşturma başarısının ölçümü; düşük değer = iyi temsil.
#
#
# ### Model Monitoring & Deployment Metrics
#
# **During Training**
# - **Training vs Validation Loss** → Overfitting / underfitting analizi için loss eğrileri.
# - **Learning Rate Schedule** → Training stabilitesini izleme parametresi.
# - **Epoch-wise Accuracy / Loss** → Modelin epoch bazlı iyileşme trendi.
#
# **Post-Deployment**
# - **Data Drift / Concept Drift** → Üretim verisinin eğitim dağılımından sapma miktarı.
# - **Latency & Throughput** → Model servis performansı metrikleri.
# - **Serving Accuracy / Live A/B Test Results** → Gerçek kullanıcı verisiyle model değerlendirmesi.
#
# </details>
#
# <details>
#
# <summary><b>🧰 Bilinmesi Gereken Frameworkler ve Araçlar</b></summary>
#
# **Veri Hazırlama & Görselleştirme**
# - **pandas** → Tabular data manipulation ve preprocessing için güçlü DataFrame yapısı.
# - **NumPy** → Linear algebra, vectorized computation ve numerical array processing backbone.
# - **matplotlib / seaborn / plotly** → Exploratory data analysis (EDA) için visualization toolkitler.
#
# **Genel ML Frameworkleri**
# - **scikit-learn** → Core ML algoritmaları, preprocessing ve model evaluation için en yaygın Python library.
# - **XGBoost / LightGBM / CatBoost** → Gradient boosting tabanlı high-performance ensemble frameworkler.
#
# **Model İzleme & Dağıtım**
# - **MLflow** → Experiment tracking, model registry ve deployment pipeline yönetimi.
# - **Weights & Biases (W&B)** → Training metriklerinin real-time izlenmesi ve hyperparameter tracking.
# - **ONNX / TensorRT** → Model inference optimizasyonu ve cross-framework deployment.
# - **Streamlit / Gradio / FastAPI** → ML modellerini interactive web app veya API endpoint olarak deploy etme.
#
# </details>
#
# ---
#
# ### Bilinmesi Gereken Konular
# - Matematik/Olasılık/İstatistik
# - SQL- Python ve Kütüphaneleri
# - Makine Öğrenmesi (Algoritmalar, metrikler vb.)
# - Deployment
#
#
# <div style="display:flex; gap:16px; align-items:flex-start; justify-content:center;">
#   <img src="/files/./assets/ml_book.jpg" style="width:220px; height:300px; object-fit:contain;"/>
#   <img src="/files/./assets/ds_handbook.jpg" style="width:220px; height:300px; object-fit:contain;"/>
#   <img src="/files/./assets/statistics_book.jpg" style="width:220px; height:300px; object-fit:contain;"/>
# </div>
#
#
#
# ### Örnek Caseler
#
# | Kategori | Problem | Kullanılan Algoritmalar | Not |
# |-----------|----------|-------------------------|------|
# | **Finans** | Dolandırıcılık Tespiti | Random Forest, Gradient Boosting, Neural Networks | Kredi kartı veya online ödeme işlemlerinde anomali yakalama |
# | **Pazarlama** | Kişiselleştirilmiş Öneri Sistemleri | Collaborative Filtering, Matrix Factorization | E-ticaret sitelerinde ürün önerileri, kampanya kişiselleştirme |
# | **Perakende** | Optimizasyon | Regression Models, Gradient Boosting | Stok yönetimi, talep tahmini ve fiyat optimizasyonu |
# | **Ulaşım & Lojistik** | Rota Optimizasyonu | Graph Algorithms, Reinforcement Learning | Kargo teslimat sürelerini kısaltmak için rota planlama |
# | **Oyun / Simülasyon** | Gerçekçi NPC Davranışları | Reinforcement Learning (DQN, PPO) | Oyun içi yapay zekâ karakterlerinin adaptif strateji geliştirmesi [Örnek](https://www.youtube.com/watch?v=HABQTiyu4Gg)|
#
# ---

# %% [markdown]
# ### Basit Bir ML Pipeline Örneği

# %%
# Cell 1: generate synthetic credit risk data (more separable, ~18% default)
import warnings 
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd

rng = np.random.default_rng(42)
n = 6000

# Core drivers
income = rng.lognormal(mean=9.5, sigma=0.5, size=n)            # annual income (TRY)
age = rng.integers(20, 70, size=n)                             # age
debt_ratio = np.clip(rng.normal(0.35, 0.15, size=n), 0, 1)     # debt/income
late_payments = rng.poisson(lam=1.3, size=n)                   # # of late pays in last 12m
num_accounts = rng.integers(1, 12, size=n)                     # # of credit accounts
util_rate = np.clip(rng.normal(0.5, 0.2, size=n), 0, 1)        # revolving utilization

# A more separable logit: stronger weights on risk drivers + mild interactions
logit = (
    -2.3
    - 0.00005 * income
    + 0.015 * (50 - age)
    + 3.1 * debt_ratio
    + 0.55 * late_payments
    + 1.3 * util_rate
    + 0.35 * (num_accounts > 8)
    + 0.8 * (debt_ratio * util_rate)            # interaction increases risk
)

p = 1 / (1 + np.exp(-logit))
default = rng.binomial(1, p)

df = pd.DataFrame({
    "income": income,
    "age": age,
    "debt_ratio": debt_ratio,
    "late_payments": late_payments,
    "num_accounts": num_accounts,
    "util_rate": util_rate,
    "default": default.astype(int)
})

df.head()
# Out:
#          income  age  debt_ratio  late_payments  num_accounts  util_rate  \
# 0  15558.440066   54    0.592063              2            10   0.749803
# 1   7942.695235   52    0.508142              2             4   0.500434
# 2  19442.673570   39    0.103874              2             8   0.518645
# 3  21381.521746   58    0.552702              1             7   0.313693
# 4   5036.579226   56    0.552413              1             5   0.538611
#
#    default
# 0        1
# 1        0
# 2        0
# 3        1
# 4        0

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(context="notebook", style="whitegrid")

fig, axes = plt.subplots(1, 3, figsize=(15, 4))

# (A) Target distribution
# Rationale: Always inspect class balance before modeling.
df["default"].value_counts(normalize=True).sort_index().plot(
    kind="bar", ax=axes[0]
)
axes[0].set_xticklabels(["No Default (0)", "Default (1)"], rotation=0)
axes[0].set_title("Target Distribution")
axes[0].set_ylabel("Proportion")

# (B) Binned default rate vs debt_ratio
# Rationale: Directly shows how risk changes across feature ranges.
bins_dr = pd.cut(df["debt_ratio"], bins=np.linspace(0, 1, 11))
rate_dr = df.groupby(bins_dr)["default"].mean()
rate_dr.index = rate_dr.index.astype(str)
axes[1].plot(range(len(rate_dr)), rate_dr.values, marker="o")
axes[1].set_xticks(range(len(rate_dr)))
axes[1].set_xticklabels(rate_dr.index, rotation=45, ha="right")
axes[1].set_title("Default Rate by Debt Ratio (binned)")
axes[1].set_ylabel("Default Rate")
axes[1].set_xlabel("Debt Ratio Bin")

# (C) Correlation heatmap (features only)
# Rationale: Quick scan for multicollinearity / relationships.
corr = df.drop(columns=["default"]).corr(numeric_only=True)
sns.heatmap(corr, cmap="vlag", annot=False, ax=axes[2])
axes[2].set_title("Feature Correlations")

plt.tight_layout()
plt.show()
# Out:
# C:\Users\enesm\AppData\Local\Temp\ipykernel_27372\4095929173.py:22: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   rate_dr = df.groupby(bins_dr)["default"].mean()

# %%
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score, average_precision_score, classification_report, precision_recall_curve
import numpy as np

y = df["default"].astype(int)
X = df.drop(columns=["default"])

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, stratify=y, random_state=42
)

num_features = X_train.columns.tolist()
preprocess = ColumnTransformer(
    transformers=[("num", StandardScaler(), num_features)],
    remainder="drop"
)

clf = Pipeline(steps=[
    ("prep", preprocess),
    ("model", LogisticRegression(
        max_iter=1000,
        class_weight="balanced",   # helps with class imbalance
        random_state=42
    ))
])

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
cv_auc = cross_val_score(clf, X_train, y_train, scoring="roc_auc", cv=cv).mean()

clf.fit(X_train, y_train)
proba = clf.predict_proba(X_test)[:, 1]
roc_auc = roc_auc_score(y_test, proba)
pr_auc = average_precision_score(y_test, proba)


precision, recall, thresh = precision_recall_curve(y_test, proba)
f1_proxy = 2 * (precision * recall) / (precision + recall + 1e-12)
best_idx = np.nanargmax(f1_proxy)
best_threshold = thresh[min(best_idx, len(thresh)-1)]
pred = (proba >= best_threshold).astype(int)

print(f"CV ROC AUC (train): {cv_auc:.3f}")
print(f"Test ROC AUC      : {roc_auc:.3f}")
print(f"Test PR AUC       : {pr_auc:.3f}")
print(f"Chosen threshold  : {best_threshold:.3f}\n")
print("Classification report (with tuned threshold):\n")
print(classification_report(y_test, pred, digits=3))
# Out:
# CV ROC AUC (train): 0.732
# Test ROC AUC      : 0.736
# Test PR AUC       : 0.689
# Chosen threshold  : 0.404
#
# Classification report (with tuned threshold):
#
#               precision    recall  f1-score   support
#
#            0      0.787     0.491     0.604       844
#            1      0.559     0.829     0.667       656
#
#     accuracy                          0.639      1500
#    macro avg      0.673     0.660     0.636      1500
# weighted avg      0.687     0.639     0.632      1500

# %% [markdown]
# ## Derin Öğrenme (Deep Learning - DL)
#
# **Derin Öğrenme**, çok katmanlı yapay sinir ağlarıyla (deep neural networks) karmaşık veri örüntülerini otomatik olarak öğrenen ML alt dalıdır.
#
# ### Yapay Sinir Ağları
#
# <img src="assets/Colored_neural_network.svg.png" alt="ANN" width="300"/>
#
# ### Temel Bileşenler
#
# - **Nöronlar (Nodes)**
# - **Ağırlıklar (Weights)**
# - **Aktivasyon Fonksiyonları**
# - **Bias**
# ---
#
#
# <img src="assets/deep_learning_vs_ml.webp" alt="DL vs ML" width="600"/>
#
# [Kaynak](https://www.sprintzeal.com/blog/deep-learning-vs-machine-learning)
#
# <details>
# <summary><b>🧩 DL Çeşitleri</b></summary>
#
# **1) Görüntü (Vision)**
# - **CNN** (ResNet, EfficientNet) → Evrişimle yerel özellik yakalama.
# - **Vision Transformer (ViT)** → Patch-based self-attention ile global bağlam.
#
# **2) Dil (NLP)**
# - **Transformer** (BERT, RoBERTa, GPT) → Self-attention; uzun bağlam, transfer learning.
# - **Seq2Seq** (eski: LSTM/GRU + Attention) → Çeviri/özetleme.
#
# **3) Zaman Serisi / Sinyal**
# - **Temporal CNN / TCN**, **Transformer-Timeseries**, **LSTM/GRU** → Talep/tahmin, anomali.
#
# **4) Grafik Veriler**
# - **GNN** (GCN, GAT) → Düğümler-arası ilişki (sosyal ağ, öneri, tedarik zinciri).
#
# **5) Temsili & Üretici**
# - **Autoencoder / VAE** → Sıkıştırma, outlier.
# - **GAN / Diffusion** → Görsel üretim, data augmentation.
#
# </details>
#
#
# <details>
# <summary><b>🧰 Frameworkler ve Araçlar</b></summary>
#
# **Core**
# - **PyTorch**, **TensorFlow/Keras**, **JAX**.
#
# **Ekosistem**
# - **PyTorch Lightning** / **KerasCV** → eğitim iskeleti.
# - **Hugging Face (Transformers, Datasets, Accelerate)** → SOTA modeller & veri.
# - **Weights & Biases / MLflow** → deneme takibi, model kayıt.
# - **ONNX / TensorRT / Torch-TensorRT** → inference optimizasyonu.
# - **gradio / FastAPI / Triton** → servisleme & demo.
# </details>
#
# ---
#
# <div style="display:flex; gap:16px; align-items:flex-start; justify-content:center;">
#   <img src="/files/./assets/hands_on_ml.jpg" style="width:220px; height:300px; object-fit:contain;"/>
#   <img src="/files/./assets/dl_with_py.jpg" style="width:220px; height:300px; object-fit:contain;"/>
# </div>
#
#
# ---
#
# ### Örnek DL Caseler
#
# | Kategori | Problem | Yaklaşım / Mimari | Not |
# |---|---|---|---|
# | **Görüntü** | Üretim hattında kusur tespiti | CNN / ViT, Anomaly (AE/VAE) | Gerçek zamanlı kalite kontrol |
# | **NLP** | Müşteri destek mail sınıflandırma & özet | BERT/DistilBERT, T5 | SLA hızlanması, otomatik triage |
# | **Perakende** | Görsel arama (benzer ürün bulma) | CNN/ViT embedding + ANN | Dönüşüm artışı, UX iyileşmesi |
# | **Finans** | Sahte belge/IBAN yakalama | Vision Transformer + OCR | Fraud önleme, uyum süreçleri |
# | **Zaman Serisi** | Talep/tüketim tahmini | Transformer-TS / TCN | Tedarik & enerji planlama |
# | **Generative** | Ürün görsel üretimi | Diffusion / GAN | İçerik üretim maliyeti düşüşü |
#
# ---

# %% [markdown]
# ### Basit Bir DL Pipeline Örneği
# **Dataset:** [https://www.kaggle.com/datasets/zalando-research/fashionmnist/data](https://www.kaggle.com/datasets/zalando-research/fashionmnist/data)

# %%
# Cell 1: load Fashion-MNIST (from Kaggle), subset, split, normalize
import os, gzip, struct, numpy as np, pandas as pd
from pathlib import Path
from sklearn.model_selection import train_test_split
import tensorflow as tf
import kagglehub

np.random.seed(42); tf.random.set_seed(42)

path = kagglehub.dataset_download("zalando-research/fashionmnist")
root = Path(path)

def read_idx_images(p):
    with gzip.open(p, "rb") as f:
        _, n, r, c = struct.unpack(">IIII", f.read(16))
        return np.frombuffer(f.read(), dtype=np.uint8).reshape(n, r, c)

def read_idx_labels(p):
    with gzip.open(p, "rb") as f:
        _, n = struct.unpack(">II", f.read(8))
        return np.frombuffer(f.read(), dtype=np.uint8)

# detect format
has_idx = any(root.rglob("*-idx*-ubyte.gz"))
has_csv = any(root.rglob("*.csv"))

if has_idx:
    tr_x = next(root.rglob("train-images-idx3-ubyte.gz"))
    tr_y = next(root.rglob("train-labels-idx1-ubyte.gz"))
    te_x = next(root.rglob("t10k-images-idx3-ubyte.gz"))
    te_y = next(root.rglob("t10k-labels-idx1-ubyte.gz"))
    X_train_full = read_idx_images(tr_x)
    y_train_full = read_idx_labels(tr_y)
    X_test_full  = read_idx_images(te_x)
    y_test_full  = read_idx_labels(te_y)
elif has_csv:
    tr = next(p for p in root.rglob("*.csv") if "train" in p.name.lower())
    te = next(p for p in root.rglob("*.csv") if "test"  in p.name.lower())
    df_tr, df_te = pd.read_csv(tr), pd.read_csv(te)
    y_train_full = df_tr["label"].to_numpy(np.uint8)
    X_train_full = df_tr.drop(columns=["label"]).to_numpy(np.uint8).reshape(-1, 28, 28)
    y_test_full  = df_te["label"].to_numpy(np.uint8)
    X_test_full  = df_te.drop(columns=["label"]).to_numpy(np.uint8).reshape(-1, 28, 28)
else:
    raise FileNotFoundError(f"No IDX/CSV files found under {root}")

# use subsets to keep it light
n_train_subset, n_test_subset = 20_000, 5_000
idx = np.random.choice(len(X_train_full), size=n_train_subset, replace=False)
X_small, y_small = X_train_full[idx], y_train_full[idx]
X_test = X_test_full[:n_test_subset]
y_test = y_test_full[:n_test_subset]

# split + normalize + channel dim
X_train, X_val, y_train, y_val = train_test_split(
    X_small, y_small, test_size=0.1, stratify=y_small, random_state=42
)

def to_tensor(x):
    x = x.astype("float32") / 255.0
    return np.expand_dims(x, -1)

X_train, X_val, X_test = map(to_tensor, [X_train, X_val, X_test])
num_classes = int(len(np.unique(y_train)))

print("Shapes:",
      "\n  train:", X_train.shape, y_train.shape,
      "\n  val  :", X_val.shape,   y_val.shape,
      "\n  test :", X_test.shape,  y_test.shape,
      "\n  num_classes:", num_classes)
# Out:
# Shapes:
#   train: (18000, 28, 28, 1) (18000,)
#   val  : (2000, 28, 28, 1) (2000,)
#   test : (5000, 28, 28, 1) (5000,)
#   num_classes: 10

# %%
# Cell 2: define & train model
from tensorflow.keras import layers, models, callbacks

def make_cnn(input_shape=(28, 28, 1), num_classes=10):
    m = models.Sequential([
        layers.Conv2D(32, 3, activation="relu", input_shape=input_shape),
        layers.Conv2D(32, 3, activation="relu"),
        layers.MaxPooling2D(), layers.Dropout(0.25),
        layers.Conv2D(64, 3, activation="relu"),
        layers.MaxPooling2D(), layers.Dropout(0.25),
        layers.Flatten(),
        layers.Dense(128, activation="relu"), layers.Dropout(0.3),
        layers.Dense(num_classes, activation="softmax"),
    ])
    m.compile(optimizer="adam",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])
    return m

model = make_cnn(input_shape=(28,28,1), num_classes=num_classes)
es = callbacks.EarlyStopping(monitor="val_accuracy", patience=3, restore_best_weights=True)

hist = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=10,
    batch_size=128,
    callbacks=[es],
    verbose=1
)
# Out:
# Epoch 1/10
# WARNING:tensorflow:From C:\Users\enesm\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\enesm\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 141/141 [==============================] - 9s 47ms/step - loss: 0.9266 - accuracy: 0.6527 - val_loss: 0.5486 - val_accuracy: 0.7935
# Epoch 2/10
# 141/141 [==============================] - 6s 40ms/step - loss: 0.5521 - accuracy: 0.7919 - val_loss: 0.4740 - val_accuracy: 0.8360
# Epoch 3/10
# 141/141 [==============================] - 6s 40ms/step - loss: 0.4773 - accuracy: 0.8268 - val_loss: 0.4207 - val_accuracy: 0.8540
# Epoch 4/10
# ...

# %%
# Cell 3: evaluate & plot
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report

test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"Test accuracy: {test_acc:.3f} | Test loss: {test_loss:.3f}")

plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.plot(hist.history["loss"], label="train")
plt.plot(hist.history["val_loss"], label="val"); plt.title("Loss"); plt.legend()
plt.subplot(1,2,2)
plt.plot(hist.history["accuracy"], label="train")
plt.plot(hist.history["val_accuracy"], label="val"); plt.title("Accuracy"); plt.legend()
plt.tight_layout(); plt.show()

y_pred = model.predict(X_test[:2000], verbose=0).argmax(axis=1)
print(classification_report(y_test[:2000], y_pred, digits=3))
# Out:
# Test accuracy: 0.896 | Test loss: 0.282
#               precision    recall  f1-score   support
#
#            0      0.820     0.862     0.840       195
#            1      0.989     0.984     0.987       189
#            2      0.901     0.751     0.819       205
#            3      0.958     0.920     0.939       200
#            4      0.797     0.910     0.850       199
#            5      0.975     0.980     0.978       202
#            6      0.693     0.732     0.712       213
#            7      0.959     0.917     0.937       204
#            8      0.994     0.947     0.970       188
#            9      0.926     0.971     0.948       205
#
#     accuracy                          0.895      2000
#    macro avg      0.901     0.897     0.898      2000
# weighted avg      0.899     0.895     0.896      2000

# %% [markdown]
# # 3. Doğal Dil İşleme (Natural Language Processing - NLP)
#
# **Natural Language Processing (Doğal Dil İşleme)**, bilgisayarların insan dilini anlama, yorumlama ve üretme yeteneğini geliştiren yapay zeka alt dalıdır. GenAI'nin temelini oluşturur.
#
# <img src="assets/what-is-natual-language-processsing.png" alt="NLP" width="500"/>
#
# [Kaynak](https://www.qtravel.ai/blog/what-is-natural-language-processing-and-how-do-chatgpt-systems-work/)
#
#
# ### NLP Görev Türleri
#
# - **Text Classification** → Belgeleri kategori veya sentiment etiketlerine ayırma.
# - **Named Entity Recognition (NER)** → Metin içinde kişi, organizasyon, lokasyon gibi varlıkları tanıma. [Örnek](https://huggingface.co/spaces/enesmanan/RoBERTa-Ner-Analysis)
# - **Part-of-Speech (POS) Tagging** → Kelimelere dilbilgisel kategoriler atama.
# - **Machine Translation** → Kaynak dili hedef dile çevirme.
# - **Text Generation** → Language model ile yeni metin üretimi.
# - **Question Answering / Reading Comprehension** → Metinden sorulara doğru yanıt çıkarma.
#
# ---
#
# <details>
# <summary><b>🧩 NLP Algoritmaları & Modeller</b></summary>
#
# **Classical / Feature-Based Models**
# - **Bag-of-Words (BoW)** → Kelime frekansı tabanlı sparse representation.
# - **TF-IDF** → Term importance weighting ile feature extraction.
# - **Naive Bayes** → Probabilistic classification, text-based tasks.
# - **SVM / Logistic Regression** → Feature vector üzerinden lineer sınıflandırma.
#
# **Neural / Deep Learning Models**
# - **Word2Vec / GloVe** → Static word embeddings, semantic similarity capture.
# - **RNN / LSTM / GRU** → Sequence modeling, context propagation.
# - **Transformer / BERT / GPT** → Self-attention tabanlı contextual embeddings, state-of-the-art performance.
# - **Seq2Seq / T5 / BART** → Encoder-decoder yapı, text generation ve translation.
#
# </details>
#
# <details>
# <summary><b>🧱 Tipik NLP Pipeline</b></summary>
#
# 1) **Veri Hazırlama** → Temizleme, normalizasyon, dil/encoding tespiti, dedup
# 2) **Tokenizasyon & Parçalama** → WordPiece/BPE/SentencePiece, alt-parça düzeyi
# 3) **Temsil** → TF–IDF veya **embedding** (statik ya da **contextual**)
# 4) **Model** → Klasik (LR/SVM) veya **Transformer fine-tuning**
# 5) **Değerlendirme** → Görev-özel metrikler (F1, NDCG, ROUGE …)
# 6) **Dağıtım & İzleme** → Latency/throughput, **drift**, kalite/zarar metrikleri
# </details>
#
# <details>
# <summary><b>🧰 Frameworkler ve Araçlar</b></summary>
#
# - **Hugging Face Transformers** → Pretrained transformer modelleri, fine-tuning ve tokenization.
# - **spaCy** → Tokenization, POS tagging, NER ve pipeline yönetimi.
# - **NLTK** → Classic NLP utilities, preprocessing, corpora.
# - **Gensim** → Topic modeling ve word embedding training.
# - **SentencePiece / Tokenizers** → Subword tokenization ve vocabulary management.
# - **Zemberek** → Türkçe NLP toolkit.
# </details>
#
#
# genai öncesi chatbotlar nasıl yapılıyordu
# https://github.com/Hack-the-Insurance/faq-chatbot
#
# ---
#
# <div style="display:flex; gap:16px; align-items:flex-start; justify-content:center;">
#   <img src="/files/./assets/practical_nlp.jpg" style="width:220px; height:300px; object-fit:contain;"/>
#   <img src="/files/./assets/nlp_with_python.jpg" style="width:220px; height:300px; object-fit:contain;"/>
#   <img src="/files/./assets/nlp_with_transformers.jpg" style="width:220px; height:300px; object-fit:contain;"/>
# </div>
#
# ---
#
# ### Örnek NLP Caseler
#
# | Kategori | Problem | Yaklaşım / Model | Not |
# |---|---|---|---|
# | **Müşteri Destek** | E-posta/ticket sınıflandırma & özetleme | BERT/DistilBERT sınıflandırma, T5/BART özetleme | SLA düşürme, otomatik yönlendirme |
# | **E-Ticaret** | Arama & öneri için metin benzerliği | SBERT/Contriever + FAISS | Dönüşüm artışı, semantic search |
# | **Finans** | Uyum & risk metin taraması | NER + rule hybrid, Doc classification | Regülasyon uyumu, risk sinyali |
# | **Sağlık** | Klinik notlardan varlık/ilişki çıkarımı | ClinicalBERT + NER/RE | Yapılandırılmış veri üretimi |
# | **Hukuk** | Sözleşme madde sınıflandırma/özet | Longformer/LED + özetleme | Hızlı inceleme, bilgi çekimi |
# | **Sosyal Medya** | Zararlı içerik tespiti (toxicity) | Multi-label classifier, zero-shot | Moderasyon, marka güvenliği |
#
# ---

# %% [markdown]
# ## Generative AI (GenAI)
#
# **Generative AI**, metin, görsel, ses, video ve kod gibi içerikleri **üretebilen** ya da mevcut içeriği **dönüştürebilen** modellerin bütünüdür. Büyük dil modelleri (LLM) ve difüzyon modelleri ve en yaygın mimarilerdir.
#
# <img src="assets/genai_types.jpg" alt="NLP" width="800"/>
#
# [Kaynak](https://gaiinsights.com/blog/10-types-of-generative-ai)
#
#
# <img src="assets/genai_landscape.png" alt="NLP" width="800"/>
#
# [Kaynak](https://www.linkedin.com/pulse/gen-ai-enables-top-tools-may-2025-brian-atkiss-lpgte/)
#
# ---
#
# <div style="display:flex; gap:16px; align-items:flex-start; justify-content:center;">
#   <img src="/files/./assets/ai_eng_book.jpg" style="width:220px; height:300px; object-fit:contain;"/>
#   <img src="/files/./assets/hands_on_llm_book.png" style="width:220px; height:300px; object-fit:contain;"/>
#   <img src="/files/./assets/llm_from_scratch.jpg" style="width:220px; height:300px; object-fit:contain;"/>
#
# </div>
#
# ---
#
#
# **Traditional AI**: "Bu e-posta spam mi?" → Evet/Hayır
# **Generative AI**: "Bu ürün hakkında e-posta yaz" → Yeni içerik
#
# ### Örnek GenAI Caseler
#
# | Kategori | Problem | Yaklaşım / Model | Not |
# |---|---|---|---|
# | **Müşteri Destek** | Çok dilli destek asistanı | LLM + RAG + tool-use | Politika/KB ile grounded yanıt |
# | **Ürün & Pazarlama** | Kreatif metin/görsel üretimi | LLM + Diffusion (ControlNet) | A/B varyantları, marka tonu |
# | **Yazılım** | Kod tamamlama & test üretimi | Code LLM + unit test runner | pass@k ve güvenli yürütme |
# | **Belge İşleme** | Sözleşme özet/yeniden yazım | LLM (encoder–decoder/decoder) | Kırmızı bayrak/sitasyon ekleme |
# | **Arama & Analitik** | Soru→SQL / semantic BI | LLM + SQL guardrails + RAG | Veri yönetişimi kontrolleri |
# | **Tasarım/Üretim** | Ürün görsel/variasyon | Latent Diffusion + prompt rehberi | On-brand, hızlı iterasyon |
# | **Eğitim** | İçerik, quiz, geri bildirim | LLM + seviye ayarlı prompting | Bireyselleştirilmiş öğrenme |
# | **Gizlilik & Test** | Sentetik veri üretimi | GAN/Diffusion/LLM + kısıtlar | PII sızdırmadan test verisi |
#
# ---

# %% [markdown]
# ## Bu bootcampdeki projeyi yapabilmek için bunlardan hangilerini bilmek gerekli?
